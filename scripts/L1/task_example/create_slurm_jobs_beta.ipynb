# %% [markdown]
# ## beta

# %%
model_path = '/data00/projects/MURI/scripts/jupyterhub_users/CNLab/first_level_models/cuereact/task-cuereact_model-beta.json'
# %run '/data00/projects/MURI/scripts/jupyterhub_users/CNLab/cnlab_pipeline/L1/l1analysis_notebook.ipynb'
# Out:
# Using template template-muri_beta.json: MURI default pipeline
# 	6mm FWHM smoothing
# 	No global scaling
# 	FAST correlation
# 	Euclidean translation, rotation (+ derivatives) and motion artifact (trash) regressor
# Using template task-cuereact_beta.json: cuereact task beta-series
# ----
# Processing 110 participants:
# ...
