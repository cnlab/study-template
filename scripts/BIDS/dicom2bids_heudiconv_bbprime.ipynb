# %% [markdown]
# # DICOM-to-BIDS conversion using `heudiconv` and `singularity`
#
# * This notebook walks through the steps for doing DICOM to BIDS conversion using `heudiconv` with the Singularity image.
#
#
# * This should replace the older `dcm2bids` scripts we had.
#
#
# * For a new project the initial configuration steps will need to be completed to create the `heuristic.py` file. But this only needs to be done once and then it should be straight forward to run new participants.
#
# * There is a tutorial on using heudiconv:
#     - http://reproducibility.stanford.edu/bids-tutorial-series-part-2a/
#
#   that was used as a basis for this but required some tweaks.
#
#
# #### HISTORY
#
# * 4/1/20 mbod - initial setup for MURI DICOMS

# %% [markdown]
# ## Location of files
#
# 1. DICOMS for UPenn MURI data are in:
#     ```
#     /fmriDataRaw/fmri_data_raw/bbprime/
#
#     ```
#
#     * DICOMS (`.dcm` files) should match:
#     ```
#     /fmriDataRaw/fmri_data_raw/bbprime/{subject}/{scan}/*.dcm
#     ```
#
#
# 2. BIDS files for bbprime should be in
#     ```
#     /data00/projects/bbprime/data/bids_data
#     ```
#
# 3. Config files for `heudiconv` will be in
#     ```
#     /data00/projects/bbprime/scripts/BIDS/heudiconv
#     ```

# %%
ls /fmriDataRaw/fmri_data_raw/bbprime/
# Out:
# BPP00/  BPP01/  BPP05/  BPP06/  BPP07/  BPP11/  BPP12/  BPP13/  BPP19/

# %%
ls  /data00/projects/bbprime/data/bids_data
# Out:
# CHANGES*                   README*     sub-BPP06/
# dataset_description.json*  README.md*  task-read_bold.json
# derivatives/               sub-BPP00/  task-share_bold.json
# participants.json*         sub-BPP01/
# participants.tsv*          sub-BPP05/

# %% [markdown]
# ### Setup

# %%
import pandas as pd

# %% [markdown]
# ## PART 1 - Creating the configuration files for a new project
#
# * For a new project you need to run `heudiconv` in heuristic mode once on a representative participant (i.e. has all the possible scans for a subject in study) and it will generate:
#     - a TSV file called `dicominfo.tsv` that contains the details of each of the scans in the dataset
#     - a Python template file called `heuristic.py` that you edit to setup the dicom volumes to NIFTI mapping
#
#
# * To run `heudiconv` in heuristic mode with Singularity image, use:
#     ```
#     !singularity run --cleanenv \
#         -B /data00/projects/bbprime/data/bids_data:/base  \
#         -B /fmriDataRaw/fmri_data_raw:/raw \
#         /data00/tools/singularity_images/heudiconv_0.8.0 \
#         -d /raw/bbprime/{subject}/*/*.dcm \
#         -o heudiconv/ -f convertall -s {subject} -c none --overwrite
#     ```
#      where
#      * `-B /data00/BIDS:/base` makes a file mapping for singularity to where the data should be written (i.e. `/data00/BIDS/{project...}`)
#      * `-B /fmriDataRaw/fmri_data_raw:/raw` maps the DICOM directory to singularity location `/raw`
#      * `/data00/tools/singularity_images/heudiconv_0.8.0` is the path to the `heudiconv` Singularity image you want to use. (On 4/22/20 that is version 0.8.0 - but this will change and we try to keep an updated version)
#      * `-d /raw/bbprime/{subject}/*/*.dcm` is the file matching template for finding DICOM files. Here `/raw` maps to `/fmriDataRaw/fmri_data_raw` so we are looking for files that end with `.dcm` in `/fmriDataRaw/fmri_data_raw/bbprime/{subject}/*/*.dcm` - where subject will be specified with the -s param, e.g. `MURI155`
#      * `-o /base/MURI/heudiconv/` is the location for output files from `heudiconv` to be written
#      * `-f convertall` means include all dicom files and scans (i.e. not just one type like anatomical or ignore localizers etc)
#      * `-c none` puts it into heuristic mode. This option specifies which tool to use to do dicom2nifti conversion and will be changed once the configuration is set up.

# %%
# !singularity run --cleanenv \
    -B /data00/projects/bbprime/data/bids_data:/base  \
    -B /fmriDataRaw/fmri_data_raw:/raw \
    /data00/tools/singularity_images/heudiconv_0.8.0 \
    -d /raw/bbprime/{subject}/*/*.dcm \
    -o heudiconv/ -f convertall -s BPP06 -c none --overwrite
# Out:
# INFO: Running heudiconv version 0.8.0 latest 0.9.0
# INFO: Need to process 1 study sessions
# INFO: PROCESSING STARTS: {'subject': 'BPP06', 'outdir': '/fmriNASTest/data00/projects/bbprime/scripts/BIDS/heudiconv/', 'session': None}
# INFO: Processing 3772 dicoms
# INFO: Analyzing 3772 dicoms
# INFO: Generated sequence info for 14 studies with 3759 entries total
# INFO: PROCESSING DONE: {'subject': 'BPP06', 'outdir': '/fmriNASTest/data00/projects/bbprime/scripts/BIDS/heudiconv/', 'session': None}

# %% [markdown]
# * The output from this run is in a hidden folder called .heudiconv

# %%
# !ls -a heudiconv/.heudiconv/BPP00/info
# !more heudiconv/code/heuristic.py
# Out:
# ls: cannot access heudiconv/.heudiconv/BPP00/info: No such file or directory
# import os
#
#
# def create_key(template, outtype=('nii.gz',), annotation_classes=None):
#     if template is None or not template:
#         raise ValueError('Template must be a valid format string')
#     return template, outtype, annotation_classes
#
#
# def infotodict(seqinfo):
#     """Heuristic evaluator for determining which runs belong where
#
#     allowed template fields - follow python string module:
#
#     item: index within category
#     subject: participant id
#     seqitem: run number during scanning
#     subindex: sub index within group
#     """
#
#     func_read=create_key('sub-{subject}/func/sub-{subject}_task-read_run-{item:0
# 1d}_bold')
#     func_share=create_key('sub-{subject}/func/sub-{subject}_task-share_run-{item
# m--More--(44%)

# %% [markdown]
# * We can look at the `dicominfo.tsv` in Pandas

# %%
scan_df=pd.read_csv('heudiconv/.heudiconv/BPP06/info/dicominfo.tsv', sep='\t')

# %%
scan_df
# Out:
#     total_files_till_now                                   example_dcm_file  \
# 0                      9  1.3.12.2.1107.5.2.43.66044.2021071413532424170...
# 1                    137  1.3.12.2.1107.5.2.43.66044.2021071413542236051...
# 2                    142  1.3.12.2.1107.5.2.43.66044.2021071413542645971...
# 3                    145  1.3.12.2.1107.5.2.43.66044.2021071413542646066...
# 4                    148  1.3.12.2.1107.5.2.43.66044.2021071413542646119...
# 5                    372  1.3.12.2.1107.5.2.43.66044.2021071413592624397...
# 6                   1185  1.3.12.2.1107.5.2.43.66044.2021071414020790336...
# 7                   1188  1.3.12.2.1107.5.2.43.66044.2021071414094325357...
# 8                   2042  1.3.12.2.1107.5.2.43.66044.2021071414110826105...
# 9                   2045  1.3.12.2.1107.5.2.43.66044.2021071414190592820...
# 10                  2899  1.3.12.2.1107.5.2.43.66044.2021071414193727268...
# 11                  2902  1.3.12.2.1107.5.2.43.66044.2021071414273444043...
# 12                  3756  1.3.12.2.1107.5.2.43.66044.2021071414280718132...
# 13                  3759  1.3.12.2.1107.5.2.43.66044.2021071414360476758...
#
#                    series_id  \
# 0     1-localizer_multislice
# 1             2-AAHead_Scout
# 2             3-AAHead_Scout
# 3             4-AAHead_Scout
# 4             5-AAHead_Scout
# 5      6-MPRAGE_TI1100_ipat2
# 6     7-task-read_run-1_bold
# 7      8-task-read_run-1_epi
# 8    9-task-share_run-1_bold
# 9    10-task-share_run-1_epi
# 10  11-task-share_run-2_bold
# 11   12-task-share_run-2_epi
# 12  13-task-share_run-3_bold
# 13   14-task-share_run-3_epi
#
#                                          dcm_dir_name  series_files  \
# 0   1.3.12.2.1107.5.2.43.66044.2021071413531829780...             9
# 1   1.3.12.2.1107.5.2.43.66044.2021071413542235964...           128
# 2   1.3.12.2.1107.5.2.43.66044.2021071413542644312...             5
# 3   1.3.12.2.1107.5.2.43.66044.2021071413542644354...             3
# 4   1.3.12.2.1107.5.2.43.66044.2021071413542644376...             3
# 5   1.3.12.2.1107.5.2.43.66044.2021071413553130434...           224
# 6   1.3.12.2.1107.5.2.43.66044.2021071414015597889...           813
# 7   1.3.12.2.1107.5.2.43.66044.2021071414093378038...             3
# 8   1.3.12.2.1107.5.2.43.66044.2021071414094352151...           854
# 9   1.3.12.2.1107.5.2.43.66044.2021071414185584301...             3
# 10  1.3.12.2.1107.5.2.43.66044.2021071414190640280...           854
# 11  1.3.12.2.1107.5.2.43.66044.2021071414272447406...             3
# 12  1.3.12.2.1107.5.2.43.66044.2021071414273492379...           854
# 13  1.3.12.2.1107.5.2.43.66044.2021071414355467008...             3
#
#     unspecified  dim1  dim2  dim3  dim4  ...  study_description  \
# 0           NaN   512   512     9     1  ...        CAMRIS^Falk
# 1           NaN   160   160   128     1  ...        CAMRIS^Falk
# 2           NaN   162   162     5     1  ...        CAMRIS^Falk
# 3           NaN   162   162     3     1  ...        CAMRIS^Falk
# 4           NaN   162   162     3     1  ...        CAMRIS^Falk
# 5           NaN   256   192   224     1  ...        CAMRIS^Falk
# 6           NaN    80    80    36   813  ...        CAMRIS^Falk
# 7           NaN    80    80    36     3  ...        CAMRIS^Falk
# 8           NaN    80    80    36   854  ...        CAMRIS^Falk
# 9           NaN    80    80    36     3  ...        CAMRIS^Falk
# 10          NaN    80    80    36   854  ...        CAMRIS^Falk
# 11          NaN    80    80    36     3  ...        CAMRIS^Falk
# 12          NaN    80    80    36   854  ...        CAMRIS^Falk
# 13          NaN    80    80    36     3  ...        CAMRIS^Falk
#
#     referring_physician_name     series_description  sequence_name  \
# 0                        NaN   localizer_multislice         *fl2d1
# 1                        NaN           AAHead_Scout      *fl3d1_ns
# 2                        NaN   AAHead_Scout_MPR_sag      *fl3d1_ns
# 3                        NaN   AAHead_Scout_MPR_cor      *fl3d1_ns
# 4                        NaN   AAHead_Scout_MPR_tra      *fl3d1_ns
# 5                        NaN    MPRAGE_TI1100_ipat2     *tfl3d1_16
# 6                        NaN   task-read_run-1_bold    epfid2d1_80
# 7                        NaN    task-read_run-1_epi    epfid2d1_80
# 8                        NaN  task-share_run-1_bold    epfid2d1_80
# 9                        NaN   task-share_run-1_epi    epfid2d1_80
# 10                       NaN  task-share_run-2_bold    epfid2d1_80
# 11                       NaN   task-share_run-2_epi    epfid2d1_80
# 12                       NaN  task-share_run-3_bold    epfid2d1_80
# 13                       NaN   task-share_run-3_epi    epfid2d1_80
#
#                                            image_type  accession_number  \
# 0          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')               NaN
# 1          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')               NaN
# 2         ('DERIVED', 'PRIMARY', 'MPR', 'ND', 'NORM')               NaN
# 3         ('DERIVED', 'PRIMARY', 'MPR', 'ND', 'NORM')               NaN
# 4         ('DERIVED', 'PRIMARY', 'MPR', 'ND', 'NORM')               NaN
# 5          ('ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM')               NaN
# 6   ('ORIGINAL', 'PRIMARY', 'M', 'MB', 'ND', 'NORM...               NaN
# 7   ('ORIGINAL', 'PRIMARY', 'M', 'MB', 'ND', 'NORM...               NaN
# 8   ('ORIGINAL', 'PRIMARY', 'M', 'MB', 'ND', 'NORM...               NaN
# 9   ('ORIGINAL', 'PRIMARY', 'M', 'MB', 'ND', 'NORM...               NaN
# 10  ('ORIGINAL', 'PRIMARY', 'M', 'MB', 'ND', 'NORM...               NaN
# 11  ('ORIGINAL', 'PRIMARY', 'M', 'MB', 'ND', 'NORM...               NaN
# 12  ('ORIGINAL', 'PRIMARY', 'M', 'MB', 'ND', 'NORM...               NaN
# 13  ('ORIGINAL', 'PRIMARY', 'M', 'MB', 'ND', 'NORM...               NaN
#
#    patient_age  patient_sex      date  \
# 0          NaN            M  20210714
# 1          NaN            M  20210714
# 2          NaN            M  20210714
# 3          NaN            M  20210714
# 4          NaN            M  20210714
# 5          NaN            M  20210714
# 6          NaN            M  20210714
# 7          NaN            M  20210714
# 8          NaN            M  20210714
# 9          NaN            M  20210714
# 10         NaN            M  20210714
# 11         NaN            M  20210714
# 12         NaN            M  20210714
# 13         NaN            M  20210714
#
#                                            series_uid
# 0   1.3.12.2.1107.5.2.43.66044.2021071413531829780...
# 1   1.3.12.2.1107.5.2.43.66044.2021071413542235964...
# 2   1.3.12.2.1107.5.2.43.66044.2021071413542644312...
# 3   1.3.12.2.1107.5.2.43.66044.2021071413542644354...
# 4   1.3.12.2.1107.5.2.43.66044.2021071413542644376...
# 5   1.3.12.2.1107.5.2.43.66044.2021071413553130434...
# 6   1.3.12.2.1107.5.2.43.66044.2021071414015597889...
# 7   1.3.12.2.1107.5.2.43.66044.2021071414093378038...
# 8   1.3.12.2.1107.5.2.43.66044.2021071414094352151...
# 9   1.3.12.2.1107.5.2.43.66044.2021071414185584301...
# 10  1.3.12.2.1107.5.2.43.66044.2021071414190640280...
# 11  1.3.12.2.1107.5.2.43.66044.2021071414272447406...
# 12  1.3.12.2.1107.5.2.43.66044.2021071414273492379...
# 13  1.3.12.2.1107.5.2.43.66044.2021071414355467008...
#
# [14 rows x 26 columns]

# %% [markdown]
# * The goal is to set up a mapping between values some of these fields and a BIDS compliant file
#
#
# * The most useful fields for this are the `series_id` or `series_description` and the 4 dimension fields.
#   * `dim4` is the number of volumes and using this can help when there is a partial (i.e. scan started and stopped quickly) scan before a complete one where the `series_id` will be the same.

# %%
scan_df[['series_id', 'series_description', 'dim1','dim2','dim3','dim4']]
# Out:
#                    series_id     series_description  dim1  dim2  dim3  dim4
# 0     1-localizer_multislice   localizer_multislice   512   512     9     1
# 1             2-AAHead_Scout           AAHead_Scout   160   160   128     1
# 2             3-AAHead_Scout   AAHead_Scout_MPR_sag   162   162     5     1
# 3             4-AAHead_Scout   AAHead_Scout_MPR_cor   162   162     3     1
# 4             5-AAHead_Scout   AAHead_Scout_MPR_tra   162   162     3     1
# 5      6-MPRAGE_TI1100_ipat2    MPRAGE_TI1100_ipat2   256   192   224     1
# 6     7-task-read_run-1_bold   task-read_run-1_bold    80    80    36   813
# 7      8-task-read_run-1_epi    task-read_run-1_epi    80    80    36     3
# 8    9-task-share_run-1_bold  task-share_run-1_bold    80    80    36   854
# 9    10-task-share_run-1_epi   task-share_run-1_epi    80    80    36     3
# 10  11-task-share_run-2_bold  task-share_run-2_bold    80    80    36   854
# 11   12-task-share_run-2_epi   task-share_run-2_epi    80    80    36     3
# 12  13-task-share_run-3_bold  task-share_run-3_bold    80    80    36   854
# 13   14-task-share_run-3_epi   task-share_run-3_epi    80    80    36     3

# %% [markdown]
# * There is a Python file called `heuristic.py` that needs to be edited to set up the mappings between dicom files and these scan data and the location within the BIDS structure in the output folder.
#
#
# * The two things that need to be added to this files are:
#     1. __KEYS__ that provide a file template and mapping to where in the BIDS output a certain filetype should be written
#     2. __MATCHES__ are condition statements that match a scan using the fields in the dataframe above and map them to a specific key
#
#
#
# * __KEYS__
# ![](img/heudiconv1.png)
#
# * __CONDITIONAL MATCHES__
# ![](img/heudiconv2.png)

# %% [markdown]
# * Once these are added to `heuristic.py` which we keep in:
#     ```
#     /data00/BIDS/MURI/heudiconv/code
#     ```
#
#
# * and we delete the `.heudiconv` heuristic folder. Then we are ready to convert DICOM files to NIFTIs and set them up in a BIDS compliant structure!

# %%
rm -fr heudiconv/.heudiconv

# %% [markdown]
# ## PART 2 - Doing the DICOM to BIDS conversion for new data using existing config setup
#
# * Now we have set up a mapping and edited the `heuristics.py` file we can do dicom2bids conversion with the following Singularity command.
#
# * __N.B.__ Make sure the source folder in:
#    ```
#    /fmriDataRaw/fmri_data_raw/bbprime
#    ```
#
# * The only thing that needs to be changed is the subject identifier:
#    ```
#    -s BPP00
#    ```
#
#    it should match the folder name of the subject's data in
#    ```
#    /fmriDataRaw/fmri_data_raw/bbprime
#    ```

# %%
# !singularity run --cleanenv \
    -B /data00/projects/bbprime:/base  \
    -B /fmriDataRaw/fmri_data_raw:/raw \
    /data00/tools/singularity_images/heudiconv_0.8.0 \
    -d /raw/bbprime/{subject}/*/*.dcm \
    -o /base/data/bids_data/ \
    -f heudiconv/code/heuristic.py -s BPP21 -c dcm2niix -b --overwrite
# Out:
# WARNING: Could not check for version updates: No response from server in 5 seconds
# INFO: Running heudiconv version 0.8.0 latest Unknown
# INFO: Need to process 1 study sessions
# INFO: PROCESSING STARTS: {'subject': 'BPP21', 'outdir': '/base/data/bids_data/', 'session': None}
# INFO: Processing 3631 dicoms
# INFO: Analyzing 3631 dicoms
# INFO: Generated sequence info for 15 studies with 3619 entries total
# INFO: Doing conversion using dcm2niix
# INFO: Converting /base/data/bids_data/sub-BPP21/anat/sub-BPP21_T1w (224 DICOMs) -> /base/data/bids_data/sub-BPP21/anat . Converter: dcm2niix . Output types: ('nii.gz',)
# 210809-13:41:45,32 nipype.utils WARNING:
# 	 Could not check for version updates:
# No response from server in 5 seconds
# WARNING: Could not check for version updates:
# No response from server in 5 seconds
# 210809-13:41:45,589 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix_nlyq0hj/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix_nlyq0hj/convert".
# 210809-13:41:45,717 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-BPP21/anat/sub-BPP21_T1w -o . -s n -v n /tmp/dcm2niix_nlyq0hj/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-BPP21/anat/sub-BPP21_T1w -o . -s n -v n /tmp/dcm2niix_nlyq0hj/convert
# 210809-13:41:47,309 nipype.interface INFO:
# 	 stdout 2021-08-09T13:41:47.309709:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2021-08-09T13:41:47.309709:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 210809-13:41:47,310 nipype.interface INFO:
# 	 stdout 2021-08-09T13:41:47.309709:Found 224 DICOM file(s)
# INFO: stdout 2021-08-09T13:41:47.309709:Found 224 DICOM file(s)
# 210809-13:41:47,310 nipype.interface INFO:
# 	 stdout 2021-08-09T13:41:47.309709:Convert 224 DICOM as ./base/data/bids_data/sub-BPP21/anat/sub-BPP21_T1w (192x256x224x1)
# INFO: stdout 2021-08-09T13:41:47.309709:Convert 224 DICOM as ./base/data/bids_data/sub-BPP21/anat/sub-BPP21_T1w (192x256x224x1)
# 210809-13:41:47,775 nipype.interface INFO:
# 	 stdout 2021-08-09T13:41:47.775168:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-BPP21/anat/sub-BPP21_T1w.nii"
# INFO: stdout 2021-08-09T13:41:47.775168:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-BPP21/anat/sub-BPP21_T1w.nii"
# 210809-13:41:47,775 nipype.interface INFO:
# 	 stdout 2021-08-09T13:41:47.775168:Conversion required 1.856603 seconds (0.373715 for core code).
# INFO: stdout 2021-08-09T13:41:47.775168:Conversion required 1.856603 seconds (0.373715 for core code).
# 210809-13:41:47,840 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-BPP21/anat/sub-BPP21_T1w.json.
# 210809-13:41:48,320 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetas78xh3eq/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetas78xh3eq/embedder".
# 210809-13:41:48,359 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 210809-13:41:48,418 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 210809-13:41:48,420 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetas78xh3eq/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetas78xh3eq/embedder)
# ERROR: Embedding failed: 'NoneType' object is not iterable
# INFO: Post-treating /base/data/bids_data/sub-BPP21/anat/sub-BPP21_T1w.json file
# INFO: Converting /base/data/bids_data/sub-BPP21/func/sub-BPP21_task-read_run-1_bold (813 DICOMs) -> /base/data/bids_data/sub-BPP21/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 210809-13:41:50,697 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixfpi4030o/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixfpi4030o/convert".
# 210809-13:41:51,6 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-BPP21/func/sub-BPP21_task-read_run-1_bold -o . -s n -v n /tmp/dcm2niixfpi4030o/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-BPP21/func/sub-BPP21_task-read_run-1_bold -o . -s n -v n /tmp/dcm2niixfpi4030o/convert
# 210809-13:42:05,246 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:05.246022:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2021-08-09T13:42:05.246022:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 210809-13:42:05,260 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:05.246022:Found 813 DICOM file(s)
# INFO: stdout 2021-08-09T13:42:05.246022:Found 813 DICOM file(s)
# 210809-13:42:05,260 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:05.246022:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2021-08-09T13:42:05.246022:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 210809-13:42:05,260 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:05.246022:Convert 813 DICOM as ./base/data/bids_data/sub-BPP21/func/sub-BPP21_task-read_run-1_bold (80x80x36x813)
# INFO: stdout 2021-08-09T13:42:05.246022:Convert 813 DICOM as ./base/data/bids_data/sub-BPP21/func/sub-BPP21_task-read_run-1_bold (80x80x36x813)
# 210809-13:42:06,787 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:06.787721:Warning: Failed to execute: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-BPP21/func/sub-BPP21_task-read_run-1_bold.nii"
# INFO: stdout 2021-08-09T13:42:06.787721:Warning: Failed to execute: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-BPP21/func/sub-BPP21_task-read_run-1_bold.nii"
# 210809-13:42:06,788 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:06.787721:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-BPP21/func/sub-BPP21_task-read_run-1_bold.nii"
# INFO: stdout 2021-08-09T13:42:06.787721:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-BPP21/func/sub-BPP21_task-read_run-1_bold.nii"
# 210809-13:42:06,788 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:06.787721:Conversion required 15.689930 seconds (3.259719 for core code).
# INFO: stdout 2021-08-09T13:42:06.787721:Conversion required 15.689930 seconds (3.259719 for core code).
# 210809-13:42:07,343 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 210809-13:42:10,343 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetao412_ddm/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetao412_ddm/embedder".
# 210809-13:42:10,739 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 210809-13:42:10,774 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 210809-13:42:10,778 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetao412_ddm/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetao412_ddm/embedder)
# ERROR: Embedding failed: 'NoneType' object is not iterable
# INFO: Post-treating /base/data/bids_data/sub-BPP21/func/sub-BPP21_task-read_run-1_bold.json file
# INFO: Converting /base/data/bids_data/sub-BPP21/func/sub-BPP21_task-share_run-1_bold (854 DICOMs) -> /base/data/bids_data/sub-BPP21/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 210809-13:42:12,814 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixp4qr50fc/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixp4qr50fc/convert".
# 210809-13:42:13,130 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-BPP21/func/sub-BPP21_task-share_run-1_bold -o . -s n -v n /tmp/dcm2niixp4qr50fc/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-BPP21/func/sub-BPP21_task-share_run-1_bold -o . -s n -v n /tmp/dcm2niixp4qr50fc/convert
# 210809-13:42:27,33 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:27.032803:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2021-08-09T13:42:27.032803:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 210809-13:42:27,37 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:27.032803:Found 854 DICOM file(s)
# INFO: stdout 2021-08-09T13:42:27.032803:Found 854 DICOM file(s)
# 210809-13:42:27,37 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:27.032803:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2021-08-09T13:42:27.032803:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 210809-13:42:27,37 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:27.032803:Convert 854 DICOM as ./base/data/bids_data/sub-BPP21/func/sub-BPP21_task-share_run-1_bold (80x80x36x854)
# INFO: stdout 2021-08-09T13:42:27.032803:Convert 854 DICOM as ./base/data/bids_data/sub-BPP21/func/sub-BPP21_task-share_run-1_bold (80x80x36x854)
# 210809-13:42:33,125 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:33.125038:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-BPP21/func/sub-BPP21_task-share_run-1_bold.nii"
# INFO: stdout 2021-08-09T13:42:33.125038:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-BPP21/func/sub-BPP21_task-share_run-1_bold.nii"
# 210809-13:42:33,125 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:33.125038:Conversion required 19.835184 seconds (2.974624 for core code).
# INFO: stdout 2021-08-09T13:42:33.125038:Conversion required 19.835184 seconds (2.974624 for core code).
# 210809-13:42:33,864 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 210809-13:42:35,213 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetalq0elphw/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetalq0elphw/embedder".
# 210809-13:42:35,342 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 210809-13:42:35,373 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 210809-13:42:35,377 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetalq0elphw/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetalq0elphw/embedder)
# ERROR: Embedding failed: 'NoneType' object is not iterable
# INFO: Post-treating /base/data/bids_data/sub-BPP21/func/sub-BPP21_task-share_run-1_bold.json file
# INFO: Converting /base/data/bids_data/sub-BPP21/func/sub-BPP21_task-share_run-2_bold (854 DICOMs) -> /base/data/bids_data/sub-BPP21/func . Converter: dcm2niix . Output types: ('nii.gz',)
# 210809-13:42:37,617 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixjplr_5jl/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixjplr_5jl/convert".
# 210809-13:42:37,923 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-BPP21/func/sub-BPP21_task-share_run-2_bold -o . -s n -v n /tmp/dcm2niixjplr_5jl/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-BPP21/func/sub-BPP21_task-share_run-2_bold -o . -s n -v n /tmp/dcm2niixjplr_5jl/convert
# 210809-13:42:45,105 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:45.105561:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2021-08-09T13:42:45.105561:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 210809-13:42:45,106 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:45.105561:Found 854 DICOM file(s)
# INFO: stdout 2021-08-09T13:42:45.105561:Found 854 DICOM file(s)
# 210809-13:42:45,106 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:45.105561:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2021-08-09T13:42:45.105561:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 210809-13:42:45,106 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:45.105561:Convert 854 DICOM as ./base/data/bids_data/sub-BPP21/func/sub-BPP21_task-share_run-2_bold (80x80x36x854)
# INFO: stdout 2021-08-09T13:42:45.105561:Convert 854 DICOM as ./base/data/bids_data/sub-BPP21/func/sub-BPP21_task-share_run-2_bold (80x80x36x854)
# 210809-13:42:50,650 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:50.650364:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-BPP21/func/sub-BPP21_task-share_run-2_bold.nii"
# INFO: stdout 2021-08-09T13:42:50.650364:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-BPP21/func/sub-BPP21_task-share_run-2_bold.nii"
# 210809-13:42:50,650 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:50.650364:Conversion required 12.641788 seconds (2.387361 for core code).
# INFO: stdout 2021-08-09T13:42:50.650364:Conversion required 12.641788 seconds (2.387361 for core code).
# 210809-13:42:51,111 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# 210809-13:42:52,342 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetack530zj3/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetack530zj3/embedder".
# 210809-13:42:52,426 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 210809-13:42:52,447 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 210809-13:42:52,451 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetack530zj3/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetack530zj3/embedder)
# ERROR: Embedding failed: 'NoneType' object is not iterable
# INFO: Post-treating /base/data/bids_data/sub-BPP21/func/sub-BPP21_task-share_run-2_bold.json file
# INFO: Converting /base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-1_dir-AP_epi (3 DICOMs) -> /base/data/bids_data/sub-BPP21/fmap . Converter: dcm2niix . Output types: ('nii.gz',)
# 210809-13:42:52,573 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixzdkfkm2k/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixzdkfkm2k/convert".
# 210809-13:42:52,581 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-1_dir-AP_epi -o . -s n -v n /tmp/dcm2niixzdkfkm2k/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-1_dir-AP_epi -o . -s n -v n /tmp/dcm2niixzdkfkm2k/convert
# 210809-13:42:52,677 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:52.677119:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2021-08-09T13:42:52.677119:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 210809-13:42:52,677 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:52.677119:Found 3 DICOM file(s)
# INFO: stdout 2021-08-09T13:42:52.677119:Found 3 DICOM file(s)
# 210809-13:42:52,677 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:52.677119:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2021-08-09T13:42:52.677119:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 210809-13:42:52,677 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:52.677119:Convert 3 DICOM as ./base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-1_dir-AP_epi (80x80x36x3)
# INFO: stdout 2021-08-09T13:42:52.677119:Convert 3 DICOM as ./base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-1_dir-AP_epi (80x80x36x3)
# 210809-13:42:52,769 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:52.769631:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-1_dir-AP_epi.nii"
# INFO: stdout 2021-08-09T13:42:52.769631:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-1_dir-AP_epi.nii"
# 210809-13:42:52,769 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:52.769631:Conversion required 0.168047 seconds (0.034930 for core code).
# INFO: stdout 2021-08-09T13:42:52.769631:Conversion required 0.168047 seconds (0.034930 for core code).
# 210809-13:42:52,808 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-1_dir-AP_epi.json.
# 210809-13:42:52,924 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmeta599ghi5v/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmeta599ghi5v/embedder".
# 210809-13:42:52,933 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 210809-13:42:52,953 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 210809-13:42:52,954 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmeta599ghi5v/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmeta599ghi5v/embedder)
# ERROR: Embedding failed: 'NoneType' object is not iterable
# INFO: Post-treating /base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-1_dir-AP_epi.json file
# INFO: Converting /base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-2_dir-AP_epi (3 DICOMs) -> /base/data/bids_data/sub-BPP21/fmap . Converter: dcm2niix . Output types: ('nii.gz',)
# 210809-13:42:53,9 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niixhhld_ov5/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niixhhld_ov5/convert".
# 210809-13:42:53,15 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-2_dir-AP_epi -o . -s n -v n /tmp/dcm2niixhhld_ov5/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-2_dir-AP_epi -o . -s n -v n /tmp/dcm2niixhhld_ov5/convert
# 210809-13:42:53,99 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:53.099693:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2021-08-09T13:42:53.099693:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 210809-13:42:53,100 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:53.099693:Found 3 DICOM file(s)
# INFO: stdout 2021-08-09T13:42:53.099693:Found 3 DICOM file(s)
# 210809-13:42:53,100 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:53.099693:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2021-08-09T13:42:53.099693:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 210809-13:42:53,100 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:53.099693:Convert 3 DICOM as ./base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-2_dir-AP_epi (80x80x36x3)
# INFO: stdout 2021-08-09T13:42:53.099693:Convert 3 DICOM as ./base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-2_dir-AP_epi (80x80x36x3)
# 210809-13:42:53,199 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:53.198999:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-2_dir-AP_epi.nii"
# INFO: stdout 2021-08-09T13:42:53.198999:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-2_dir-AP_epi.nii"
# 210809-13:42:53,199 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:53.198999:Conversion required 0.163912 seconds (0.037394 for core code).
# INFO: stdout 2021-08-09T13:42:53.198999:Conversion required 0.163912 seconds (0.037394 for core code).
# 210809-13:42:53,244 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-2_dir-AP_epi.json.
# 210809-13:42:53,358 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetah9_a_sfc/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetah9_a_sfc/embedder".
# 210809-13:42:53,366 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 210809-13:42:53,386 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 210809-13:42:53,387 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetah9_a_sfc/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetah9_a_sfc/embedder)
# ERROR: Embedding failed: 'NoneType' object is not iterable
# INFO: Post-treating /base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-2_dir-AP_epi.json file
# INFO: Converting /base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-3_dir-AP_epi (3 DICOMs) -> /base/data/bids_data/sub-BPP21/fmap . Converter: dcm2niix . Output types: ('nii.gz',)
# 210809-13:42:53,435 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix9j3_qrkw/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix9j3_qrkw/convert".
# 210809-13:42:53,444 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-3_dir-AP_epi -o . -s n -v n /tmp/dcm2niix9j3_qrkw/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-3_dir-AP_epi -o . -s n -v n /tmp/dcm2niix9j3_qrkw/convert
# 210809-13:42:53,519 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:53.518969:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2021-08-09T13:42:53.518969:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 210809-13:42:53,519 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:53.518969:Found 3 DICOM file(s)
# INFO: stdout 2021-08-09T13:42:53.518969:Found 3 DICOM file(s)
# 210809-13:42:53,519 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:53.518969:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2021-08-09T13:42:53.518969:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 210809-13:42:53,520 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:53.518969:Convert 3 DICOM as ./base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-3_dir-AP_epi (80x80x36x3)
# INFO: stdout 2021-08-09T13:42:53.518969:Convert 3 DICOM as ./base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-3_dir-AP_epi (80x80x36x3)
# 210809-13:42:53,614 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:53.614129:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-3_dir-AP_epi.nii"
# INFO: stdout 2021-08-09T13:42:53.614129:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-3_dir-AP_epi.nii"
# 210809-13:42:53,614 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:53.614129:Conversion required 0.147708 seconds (0.036201 for core code).
# INFO: stdout 2021-08-09T13:42:53.614129:Conversion required 0.147708 seconds (0.036201 for core code).
# 210809-13:42:53,648 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-3_dir-AP_epi.json.
# 210809-13:42:53,767 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetawzo2p38t/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetawzo2p38t/embedder".
# 210809-13:42:53,780 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 210809-13:42:53,802 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 210809-13:42:53,803 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetawzo2p38t/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetawzo2p38t/embedder)
# ERROR: Embedding failed: 'NoneType' object is not iterable
# INFO: Post-treating /base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-3_dir-AP_epi.json file
# INFO: Converting /base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-4_dir-AP_epi (3 DICOMs) -> /base/data/bids_data/sub-BPP21/fmap . Converter: dcm2niix . Output types: ('nii.gz',)
# 210809-13:42:53,847 nipype.workflow INFO:
# 	 [Node] Setting-up "convert" in "/tmp/dcm2niix57r_1le0/convert".
# INFO: [Node] Setting-up "convert" in "/tmp/dcm2niix57r_1le0/convert".
# 210809-13:42:53,855 nipype.workflow INFO:
# 	 [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-4_dir-AP_epi -o . -s n -v n /tmp/dcm2niix57r_1le0/convert
# INFO: [Node] Running "convert" ("nipype.interfaces.dcm2nii.Dcm2niix"), a CommandLine Interface with command:
# dcm2niix -b y -z y -x n -t n -m n -f /base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-4_dir-AP_epi -o . -s n -v n /tmp/dcm2niix57r_1le0/convert
# 210809-13:42:53,927 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:53.927235:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# INFO: stdout 2021-08-09T13:42:53.927235:Chris Rorden's dcm2niiX version v1.0.20190410  GCC6.3.0 (64-bit Linux)
# 210809-13:42:53,927 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:53.927235:Found 3 DICOM file(s)
# INFO: stdout 2021-08-09T13:42:53.927235:Found 3 DICOM file(s)
# 210809-13:42:53,927 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:53.927235:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# INFO: stdout 2021-08-09T13:42:53.927235:slices stacked despite varying acquisition numbers (if this is not desired recompile with 'mySegmentByAcq')
# 210809-13:42:53,927 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:53.927235:Convert 3 DICOM as ./base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-4_dir-AP_epi (80x80x36x3)
# INFO: stdout 2021-08-09T13:42:53.927235:Convert 3 DICOM as ./base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-4_dir-AP_epi (80x80x36x3)
# 210809-13:42:54,23 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:54.022955:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-4_dir-AP_epi.nii"
# INFO: stdout 2021-08-09T13:42:54.022955:Compress: "/usr/bin/pigz" -b 960 -n -f -6 "./base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-4_dir-AP_epi.nii"
# 210809-13:42:54,23 nipype.interface INFO:
# 	 stdout 2021-08-09T13:42:54.022955:Conversion required 0.147294 seconds (0.032009 for core code).
# INFO: stdout 2021-08-09T13:42:54.022955:Conversion required 0.147294 seconds (0.032009 for core code).
# 210809-13:42:54,67 nipype.workflow INFO:
# 	 [Node] Finished "convert".
# INFO: [Node] Finished "convert".
# WARNING: Failed to find task field in /base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-4_dir-AP_epi.json.
# 210809-13:42:54,190 nipype.workflow INFO:
# 	 [Node] Setting-up "embedder" in "/tmp/embedmetacflmbe0t/embedder".
# INFO: [Node] Setting-up "embedder" in "/tmp/embedmetacflmbe0t/embedder".
# 210809-13:42:54,198 nipype.workflow INFO:
# 	 [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# INFO: [Node] Running "embedder" ("nipype.interfaces.utility.wrappers.Function")
# 210809-13:42:54,222 nipype.workflow WARNING:
# 	 Storing result file without outputs
# WARNING: Storing result file without outputs
# 210809-13:42:54,223 nipype.workflow WARNING:
# 	 [Node] Error on "embedder" (/tmp/embedmetacflmbe0t/embedder)
# WARNING: [Node] Error on "embedder" (/tmp/embedmetacflmbe0t/embedder)
# ERROR: Embedding failed: 'NoneType' object is not iterable
# INFO: Post-treating /base/data/bids_data/sub-BPP21/fmap/sub-BPP21_acq-4_dir-AP_epi.json file
# INFO: Lock 139667907909112 acquired on /base/data/bids_data/heudiconv.lock
# INFO: Populating template files under /base/data/bids_data/
# INFO: Lock 139667907909112 released on /base/data/bids_data/heudiconv.lock
# INFO: PROCESSING DONE: {'subject': 'BPP21', 'outdir': '/base/data/bids_data/', 'session': None}

# %%
# !ls /data00/projects/bbprime/data/bids_data
# !ls /data00/projects/bbprime/data/bids_data/sub-BPP01
# Out:
# CHANGES			  participants.json  README.md	task-read_bold.json
# dataset_description.json  participants.tsv   sub-BPP00	task-share_bold.json
# derivatives		  README	     sub-BPP01
# anat  fmap  sub-BPP01_scans.json  sub-BPP01_scans.tsv

# %% [markdown]
# ## Submit jobs using slurm
# The code below creates a job that can be run using slurm
#
# ### Define variables

# %%
project = 'bbprime'
project_dir = os.path.join('/data00/projects/' + project)
slurm_dir = os.path.join('/data00/slurm_jobs/slurm_' + project)
subs = ['BPP07']

job_file_template = r'''#!/bin/bash
#SBATCH --job-name=heudiconv_{ID}.job
#SBATCH --output=out/heudiconv_{ID}.out
#SBATCH --error=out/heudiconv_{ID}.err
#SBATCH --time=02:00

srun singularity run --cleanenv \
    -B /data00/projects/bbprime:/base  \
    -B /fmriDataRaw/fmri_data_raw:/raw \
    /data00/tools/singularity_images/heudiconv_0.8.0 \
    -d /raw/bbprime/{ID}/*/*.dcm \
    -o /base/data/bids_data/ \
    -f heudiconv/code/heuristic.py -s {ID} -c dcm2niix -b --overwrite
'''

# %% [markdown]
# ### Loop through specified participants

# %%
for s in subs:
    print('-------------- Creating: {} -------------'.format(s))
    
    file_path = os.path.join(slurm_dir, 'heudiconv_{}.job').format(s)
    print(file_path)

    with open(file_path.format(s), 'w') as job:
        job.write(job_file_template.format(ID=s))
# Out:
# -------------- Creating: BPP01 -------------
# /data00/slurm_jobs/slurm_bbprime/heudiconv_BPP01.job

# %% [markdown]
# ### Schedule the jobs on slurm
#
# Login to the slurm cluster:
#
# ```
# ssh <JANUS_UN>@asc.upenn.edu@cls000
# ```
#
# This will give you a terminal on the SLURM master node where you can look at the process queue and schedule jobs by pasting the output from the next chunk

# %%
print(f"cd {slurm_dir}")
for s in subs:
    print(f"sbatch -D {slurm_dir} -c 8 heudiconv_{s}.job")
# Out:
# cd /data00/slurm_jobs/slurm_bbprime
# sbatch -D /data00/slurm_jobs/slurm_bbprime -c 8 heudiconv_BPP01.job

# %%
# !ls /data00/slurm_jobs/slurm_bbprime/
# Out:
# fmriprep_sub-BPP00.job	heudiconv_BPP01.job  out
