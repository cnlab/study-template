# %% [markdown]
# # Add `IntendedFor` field in JSON files
#
# ------
#
# Specify which functional runs correspond to the fieldmaps using the `IntendedFor` field in the fmap JSON files.
#
#
# #### HISTORY
#
# * 6/12/20 dcosme - modifed existing code for this purpose

# %%
import json
import os
import re
import shutil

# %%
bids_dir = '/data00/projects/bbprime/data/bids_data/'
subs = list(filter(re.compile("sub-.*").match, os.listdir(bids_dir)))

# %% [markdown]
# ### Update file permissions

# %%
# !ls -l $bids_dir
# !chmod 777 -R $bids_dir/sub-*
# Out:
# total 5
# -rwxrwxrwx. 1 dcosme@asc.upenn.edu fmrisrv1users@asc.upenn.edu 364 Jul  9 20:29 CHANGES
# -rwxrwxrwx. 1 dcosme@asc.upenn.edu fmrisrv1users@asc.upenn.edu 633 Jul  9 20:29 dataset_description.json
# drwxrwxrwx. 1 dcosme@asc.upenn.edu fmrisrv1users@asc.upenn.edu   0 Jul 14 20:47 derivatives
# -rwxrwxrwx. 1 dcosme@asc.upenn.edu fmrisrv1users@asc.upenn.edu 405 Jul  9 20:29 participants.json
# -rwxrwxrwx. 1 dcosme@asc.upenn.edu fmrisrv1users@asc.upenn.edu 245 Aug  9 13:42 participants.tsv
# -rwxrwxrwx. 1 dcosme@asc.upenn.edu fmrisrv1users@asc.upenn.edu 138 Jul  9 20:29 README
# -rwxrwxrwx. 1 dcosme@asc.upenn.edu fmrisrv1users@asc.upenn.edu 147 Jul  9 18:30 README.md
# drwxrwxrwx. 1 dcosme@asc.upenn.edu fmrisrv1users@asc.upenn.edu   0 Jul 14 20:16 sub-BPP00
# drwxrwxrwx. 1 dcosme@asc.upenn.edu fmrisrv1users@asc.upenn.edu   0 Jul 14 20:15 sub-BPP01
# drwxrwxrwx. 1 dcosme@asc.upenn.edu fmrisrv1users@asc.upenn.edu   0 Jul 14 20:15 sub-BPP05
# drwxrwxrwx. 1 dcosme@asc.upenn.edu fmrisrv1users@asc.upenn.edu   0 Jul 14 20:15 sub-BPP06
# drwxrwxrwx. 1 dcosme@asc.upenn.edu fmrisrv1users@asc.upenn.edu   0 Aug  2 12:22 sub-BPP07
# drwxrwxrwx. 1 dcosme@asc.upenn.edu fmrisrv1users@asc.upenn.edu   0 Aug  2 12:27 sub-BPP11
# drwxrwxrwx. 1 dcosme@asc.upenn.edu fmrisrv1users@asc.upenn.edu   0 Aug  2 12:34 sub-BPP13
# drwxrwxrwx. 1 dcosme@asc.upenn.edu fmrisrv1users@asc.upenn.edu   0 Aug  2 12:39 sub-BPP19
# drwxrwxrwx. 1 dcosme@asc.upenn.edu fmrisrv1users@asc.upenn.edu   0 Aug  9 13:42 sub-BPP21
# -rw-r--r--. 1 dcosme@asc.upenn.edu fmrisrv1users@asc.upenn.edu  99 Aug  9 13:43 task-read_bold.json
# -rw-r--r--. 1 dcosme@asc.upenn.edu fmrisrv1users@asc.upenn.edu 100 Aug  9 13:43 task-share_bold.json

# %% [markdown]
# ### Define function to append IntendedFor

# %%
def add_intendedfor (SUBJ_DIR, fmap, func):
    data = json.load(open(os.path.join(SUBJ_DIR, fmap[0])))

    data['IntendedFor'] = func

    with open(os.path.join(SUBJ_DIR, fmap[0]),'w') as out:
        out.write(json.dumps(data,indent=4))

    print(data['IntendedFor'])
    print('Added IntendedFor field to JSON',fmap)

# %% [markdown]
# ### Loop through subs

# %%
for s in subs:
    SUBJ_DIR = os.path.join(bids_dir, s)

    print('\n{}'.format(s))
    print('------------------------------------')
    
    # read task
    print('\nRead task')
    fmap = [os.path.join('fmap',f) for f in os.listdir(os.path.join(SUBJ_DIR,'fmap')) if f.find('acq-1') != -1 and f.endswith('.json')]
    func = [os.path.join('func',f) for f in os.listdir(os.path.join(SUBJ_DIR,'func')) if f.find('read') != -1 and f.endswith('.nii.gz')]
    
    add_intendedfor(SUBJ_DIR, fmap, func)
 
    # share task run 1
    print('\nShare task run 1')
    fmap = [os.path.join('fmap',f) for f in os.listdir(os.path.join(SUBJ_DIR,'fmap')) if f.find('acq-2') != -1 and f.endswith('.json')]
    func = [os.path.join('func',f) for f in os.listdir(os.path.join(SUBJ_DIR,'func')) if f.find('share_run-1') != -1 and f.endswith('.nii.gz')]
    
    add_intendedfor(SUBJ_DIR, fmap, func)
    
    # share task run 2
    print('\nShare task run 2')
    fmap = [os.path.join('fmap',f) for f in os.listdir(os.path.join(SUBJ_DIR,'fmap')) if f.find('acq-3') != -1 and f.endswith('.json')]
    func = [os.path.join('func',f) for f in os.listdir(os.path.join(SUBJ_DIR,'func')) if f.find('share_run-2') != -1 and f.endswith('.nii.gz')]
    
    add_intendedfor(SUBJ_DIR, fmap, func)
    
    # share task run 3
    fmap = [os.path.join('fmap',f) for f in os.listdir(os.path.join(SUBJ_DIR,'fmap')) if f.find('acq-4') != -1 and f.endswith('.json')]
    func = [os.path.join('func',f) for f in os.listdir(os.path.join(SUBJ_DIR,'func')) if f.find('share_run-3') != -1 and f.endswith('.nii.gz')]
    
    if len(fmap) > 0:
        print('\nShare task run 3')
        add_intendedfor(SUBJ_DIR, fmap, func)
# Out:
# sub-BPP00
# ------------------------------------
#
# Read task
# ['func/sub-BPP00_task-read_run-1_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP00_acq-1_dir-AP_epi.json']
#
# Share task run 1
# ['func/sub-BPP00_task-share_run-1_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP00_acq-2_dir-AP_epi.json']
#
# Share task run 2
# ['func/sub-BPP00_task-share_run-2_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP00_acq-3_dir-AP_epi.json']
#
# sub-BPP01
# ------------------------------------
#
# Read task
# ['func/sub-BPP01_task-read_run-1_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP01_acq-1_dir-AP_epi.json']
#
# Share task run 1
# ['func/sub-BPP01_task-share_run-1_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP01_acq-2_dir-AP_epi.json']
#
# Share task run 2
# ['func/sub-BPP01_task-share_run-2_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP01_acq-3_dir-AP_epi.json']
#
# Share task run 3
# ['func/sub-BPP01_task-share_run-3_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP01_acq-4_dir-AP_epi.json']
#
# sub-BPP05
# ------------------------------------
#
# Read task
# ['func/sub-BPP05_task-read_run-1_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP05_acq-1_dir-AP_epi.json']
#
# Share task run 1
# ['func/sub-BPP05_task-share_run-1_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP05_acq-2_dir-AP_epi.json']
#
# Share task run 2
# ['func/sub-BPP05_task-share_run-2_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP05_acq-3_dir-AP_epi.json']
#
# Share task run 3
# ['func/sub-BPP05_task-share_run-3_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP05_acq-4_dir-AP_epi.json']
#
# sub-BPP06
# ------------------------------------
#
# Read task
# ['func/sub-BPP06_task-read_run-1_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP06_acq-1_dir-AP_epi.json']
#
# Share task run 1
# ['func/sub-BPP06_task-share_run-1_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP06_acq-2_dir-AP_epi.json']
#
# Share task run 2
# ['func/sub-BPP06_task-share_run-2_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP06_acq-3_dir-AP_epi.json']
#
# Share task run 3
# ['func/sub-BPP06_task-share_run-3_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP06_acq-4_dir-AP_epi.json']
#
# sub-BPP07
# ------------------------------------
#
# Read task
# ['func/sub-BPP07_task-read_run-1_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP07_acq-1_dir-AP_epi.json']
#
# Share task run 1
# ['func/sub-BPP07_task-share_run-1_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP07_acq-2_dir-AP_epi.json']
#
# Share task run 2
# ['func/sub-BPP07_task-share_run-2_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP07_acq-3_dir-AP_epi.json']
#
# Share task run 3
# ['func/sub-BPP07_task-share_run-3_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP07_acq-4_dir-AP_epi.json']
#
# sub-BPP11
# ------------------------------------
#
# Read task
# ['func/sub-BPP11_task-read_run-1_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP11_acq-1_dir-AP_epi.json']
#
# Share task run 1
# ['func/sub-BPP11_task-share_run-1_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP11_acq-2_dir-AP_epi.json']
#
# Share task run 2
# ['func/sub-BPP11_task-share_run-2_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP11_acq-3_dir-AP_epi.json']
#
# Share task run 3
# ['func/sub-BPP11_task-share_run-3_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP11_acq-4_dir-AP_epi.json']
#
# sub-BPP13
# ------------------------------------
#
# Read task
# ['func/sub-BPP13_task-read_run-1_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP13_acq-1_dir-AP_epi.json']
#
# Share task run 1
# ['func/sub-BPP13_task-share_run-1_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP13_acq-2_dir-AP_epi.json']
#
# Share task run 2
# ['func/sub-BPP13_task-share_run-2_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP13_acq-3_dir-AP_epi.json']
#
# Share task run 3
# ['func/sub-BPP13_task-share_run-3_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP13_acq-4_dir-AP_epi.json']
#
# sub-BPP19
# ------------------------------------
#
# Read task
# ['func/sub-BPP19_task-read_run-1_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP19_acq-1_dir-AP_epi.json']
#
# Share task run 1
# ['func/sub-BPP19_task-share_run-1_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP19_acq-2_dir-AP_epi.json']
#
# Share task run 2
# ['func/sub-BPP19_task-share_run-2_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP19_acq-3_dir-AP_epi.json']
#
# Share task run 3
# ['func/sub-BPP19_task-share_run-3_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP19_acq-4_dir-AP_epi.json']
#
# sub-BPP21
# ------------------------------------
#
# Read task
# ['func/sub-BPP21_task-read_run-1_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP21_acq-1_dir-AP_epi.json']
#
# Share task run 1
# ['func/sub-BPP21_task-share_run-1_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP21_acq-2_dir-AP_epi.json']
#
# Share task run 2
# ['func/sub-BPP21_task-share_run-2_bold.nii.gz']
# Added IntendedFor field to JSON ['fmap/sub-BPP21_acq-3_dir-AP_epi.json']
#
# Share task run 3
# []
# Added IntendedFor field to JSON ['fmap/sub-BPP21_acq-4_dir-AP_epi.json']
