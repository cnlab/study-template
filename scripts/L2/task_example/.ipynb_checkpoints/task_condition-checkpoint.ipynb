# %% [markdown]
# ### Instructions
#
# 1. Plug in the `model_path`
# 2. From `Run` menu, select `Restart Kernel and Run All Cells`
# 3. From `View` menu, select `Collapse All Code`

# %%
model_path = '/data00/tools/study-template/scripts/L1/task_example/task-task_condition.json'

# %%
import os, glob, re, sys, json, copy  

import nipype.interfaces.io as nio           
import nipype.interfaces.spm as spm    
import nipype.interfaces.matlab as mlab     
import nipype.pipeline.engine as pe 
import nipype.interfaces.utility as util

import pandas as pd
import numpy as np
import scipy as sp
import scipy.io as sio

from nilearn import plotting

# %%
def ensure_list(obj):
    if type(obj) is not list:
        return [obj]
    else:
        return obj

def copy_from_template(target, template):
    for key, item in template.items():
        if key not in target.keys():
            target[key] = copy.deepcopy(template[key])
        elif type(item) is dict:
            copy_from_template(target[key], template[key])

# %%
with open(model_path, 'r') as f:
    model = json.load(f)

for template_path in ensure_list(model.get("Template", [])):
    with open(template_path, 'r') as f:
        template = json.load(f)
    copy_from_template(model, template)
    
env = model['Environment']
job_name = 'task-{}_model-{}'.format(model['Info']['task'], model['Info']['model'])

# %%
env
# Out:
# {'job_path': 'models',
#  'spm_path': '/data00/tools/spm12mega',
#  'fsl_path': '/data00/tools/fsl',
#  'data_path': '/data00/projects/MURI',
#  'output_path': '/data00/projects/MURI/data/BIDS/derivatives/nipype',
#  'working_path': '/data00/projects/MURI/data/BIDS/working/nipype'}

# %%
mlab.MatlabCommand.set_default_matlab_cmd("matlab -nodesktop -nosplash")
mlab.MatlabCommand.set_default_paths(env["spm_path"])

# %%
con_df = []
print("Aggregating contrast files...")

for sub_folder in glob.glob(os.path.join(env['output_path'], job_name, 'sub-*')):
    
    if not os.path.isdir(sub_folder):
        continue
    
    sub = os.path.basename(sub_folder)
    
    spm_file = os.path.join(sub_folder, 'SPM.mat')
    if not os.path.exists(spm_file):
        continue
    
    spm_mat = sio.loadmat(spm_file, 
               squeeze_me=True, struct_as_record=False)
    
    for n, con in enumerate(spm_mat['SPM'].xCon, start=1):
        con_file = os.path.join(sub_folder, f"con_{n:04d}.nii")
        if os.path.exists(con_file):
            con_df.append({'sub': sub,
                          'con': con.name,
                          'path': con_file})
        
con_df = pd.DataFrame(con_df)
con_df.to_csv(os.path.join(env['output_path'], job_name, 'contrasts.csv'), index=False)
con_df.pivot_table(index='con', values='sub', aggfunc='count')
# Out:
# Aggregating contrast files...
#                      sub
# con
# alc_react            111
# alc_v_nonalc         111
# cue                  111
# downreg               72
# downreg_v_alc_react   72
# nonalc_react         111
# rating               111
# upreg                 34
# upreg_v_alc_react     34
# upreg_v_downreg       34

# %%
con_df_1 = con_df[con_df["con"] == "alc_v_nonalc"]

# %%
def get_contrast_files(contrast_name, contrast_df):
    return contrast_df.query(f'con == "{contrast_name}"').path.tolist()

# %%
l2analysis_path = os.path.join(env['output_path'], job_name, "l2analysis")

# %%
l2analysis = pe.Workflow(base_dir=os.path.join(env['working_path'], job_name), name='l2analysis')

infosource = pe.Node(util.IdentityInterface(fields=['contrast_name']),
                  name="infosource")
infosource.iterables = ('contrast_name', con_df.con.unique().tolist())

getcontrastfiles = pe.Node(util.Function(input_names=['contrast_name', 'contrast_df'],
                                        output_names=['contrast_files'],
                                        function=get_contrast_files),
                    name='getcontrastfiles')
getcontrastfiles.inputs.contrast_df = con_df

# One Sample T-Test Design - creates one sample T-Test Design
onesamplettestdes = pe.Node(spm.OneSampleTTestDesign(),
                         name="onesampttestdes")

# EstimateModel - estimate the parameters of the model
level2estimate = pe.Node(spm.EstimateModel(estimation_method={'Classical': 1}),
                      name="level2estimate")

# EstimateContrast - estimates simple group contrast
level2conestimate = pe.Node(spm.EstimateContrast(group_contrast=True), 
                            name="level2conestimate")
cont = ['Group', 'T', ['mean'], [1]]
level2conestimate.inputs.contrasts = [cont]

# Datasink - creates output folder for important outputs
datasink = pe.Node(nio.DataSink(base_directory=l2analysis_path), 
                   name="datasink")
datasink.inputs.substitutions = [('_contrast_name_', '')]

# Connect workflow
l2analysis.connect([(infosource, getcontrastfiles, [('contrast_name', 'contrast_name')]),
                    (getcontrastfiles, onesamplettestdes, [('contrast_files', 'in_files')]),
                    (onesamplettestdes, level2estimate, [('spm_mat_file',
                                                          'spm_mat_file')] ),
                    (level2estimate, level2conestimate, [('spm_mat_file',
                                                          'spm_mat_file'),
                                                         ('beta_images',
                                                          'beta_images'),
                                                         ('residual_image',
                                                          'residual_image')]),
                    (level2conestimate, datasink, [('spm_mat_file',
                                                    '@spm_mat'),
                                                   ('spmT_images',
                                                    '@T'),
                                                   ('con_images',
                                                    '@con')])
                   ])

l2analysis.run()
# Out:
# 210223-13:30:12,194 nipype.workflow INFO:
# 	 Workflow l2analysis settings: ['check', 'execution', 'logging', 'monitoring']
# 210223-13:30:12,782 nipype.workflow INFO:
# 	 Running serially.
# 210223-13:30:12,784 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg_v_alc_react/getcontrastfiles".
# 210223-13:30:12,972 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 210223-13:30:13,554 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 210223-13:30:13,555 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg_v_alc_react/onesampttestdes".
# 210223-13:30:13,837 nipype.workflow INFO:
# 	 [Node] Running "onesampttestdes" ("nipype.interfaces.spm.model.OneSampleTTestDesign")
# 210223-13:30:34,649 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.onesampttestdes".
# 210223-13:30:34,651 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg_v_alc_react/level2estimate".
# 210223-13:30:34,821 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 210223-13:31:17,614 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 210223-13:31:17,621 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg_v_alc_react/level2conestimate".
# 210223-13:31:17,820 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 210223-13:31:40,40 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2conestimate".
# 210223-13:31:40,41 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg_v_alc_react/datasink".
# 210223-13:31:40,205 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 210223-13:31:40,210 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg_v_alc_react/SPM.mat -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/upreg_v_alc_react/SPM.mat
# 210223-13:31:40,333 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg_v_alc_react/spmT_0001.nii -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/upreg_v_alc_react/spmT_0001.nii
# 210223-13:31:40,452 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg_v_alc_react/con_0001.nii -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/upreg_v_alc_react/con_0001.nii
# 210223-13:31:40,663 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 210223-13:31:40,665 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg_v_downreg/getcontrastfiles".
# 210223-13:31:40,890 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 210223-13:31:41,380 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 210223-13:31:41,382 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg_v_downreg/onesampttestdes".
# 210223-13:31:41,512 nipype.workflow INFO:
# 	 [Node] Running "onesampttestdes" ("nipype.interfaces.spm.model.OneSampleTTestDesign")
# 210223-13:31:59,964 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.onesampttestdes".
# 210223-13:31:59,966 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg_v_downreg/level2estimate".
# 210223-13:32:00,136 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 210223-13:32:41,154 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 210223-13:32:41,158 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg_v_downreg/level2conestimate".
# 210223-13:32:41,340 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 210223-13:33:02,141 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2conestimate".
# 210223-13:33:02,143 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg_v_downreg/datasink".
# 210223-13:33:02,290 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 210223-13:33:02,293 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg_v_downreg/SPM.mat -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/upreg_v_downreg/SPM.mat
# 210223-13:33:02,425 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg_v_downreg/spmT_0001.nii -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/upreg_v_downreg/spmT_0001.nii
# 210223-13:33:02,628 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg_v_downreg/con_0001.nii -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/upreg_v_downreg/con_0001.nii
# 210223-13:33:03,13 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 210223-13:33:03,14 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg/getcontrastfiles".
# 210223-13:33:03,202 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 210223-13:33:03,689 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 210223-13:33:03,691 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg/onesampttestdes".
# 210223-13:33:03,833 nipype.workflow INFO:
# 	 [Node] Running "onesampttestdes" ("nipype.interfaces.spm.model.OneSampleTTestDesign")
# 210223-13:33:22,505 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.onesampttestdes".
# 210223-13:33:22,507 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg/level2estimate".
# 210223-13:33:22,655 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 210223-13:34:03,98 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 210223-13:34:03,101 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg/level2conestimate".
# 210223-13:34:03,274 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 210223-13:34:22,827 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2conestimate".
# 210223-13:34:22,829 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg/datasink".
# 210223-13:34:22,969 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 210223-13:34:22,971 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg/SPM.mat -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/upreg/SPM.mat
# 210223-13:34:23,77 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg/spmT_0001.nii -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/upreg/spmT_0001.nii
# 210223-13:34:23,245 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_upreg/con_0001.nii -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/upreg/con_0001.nii
# 210223-13:34:23,400 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 210223-13:34:23,401 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_downreg_v_alc_react/getcontrastfiles".
# 210223-13:34:23,576 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 210223-13:34:24,674 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 210223-13:34:24,675 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_downreg_v_alc_react/onesampttestdes".
# 210223-13:34:24,855 nipype.workflow INFO:
# 	 [Node] Running "onesampttestdes" ("nipype.interfaces.spm.model.OneSampleTTestDesign")
# 210223-13:34:43,617 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.onesampttestdes".
# 210223-13:34:43,620 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_downreg_v_alc_react/level2estimate".
# 210223-13:34:43,829 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 210223-13:35:56,303 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 210223-13:35:56,308 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_downreg_v_alc_react/level2conestimate".
# 210223-13:35:56,563 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 210223-13:36:18,354 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2conestimate".
# 210223-13:36:18,356 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_downreg_v_alc_react/datasink".
# 210223-13:36:18,530 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 210223-13:36:18,533 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_downreg_v_alc_react/SPM.mat -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/downreg_v_alc_react/SPM.mat
# 210223-13:36:18,594 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_downreg_v_alc_react/spmT_0001.nii -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/downreg_v_alc_react/spmT_0001.nii
# 210223-13:36:18,611 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_downreg_v_alc_react/con_0001.nii -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/downreg_v_alc_react/con_0001.nii
# 210223-13:36:18,730 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 210223-13:36:18,731 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_downreg/getcontrastfiles".
# 210223-13:36:18,922 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 210223-13:36:19,926 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 210223-13:36:19,927 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_downreg/onesampttestdes".
# 210223-13:36:20,89 nipype.workflow INFO:
# 	 [Node] Running "onesampttestdes" ("nipype.interfaces.spm.model.OneSampleTTestDesign")
# 210223-13:36:39,481 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.onesampttestdes".
# 210223-13:36:39,483 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_downreg/level2estimate".
# 210223-13:36:39,636 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 210223-13:37:38,784 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 210223-13:37:38,787 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_downreg/level2conestimate".
# 210223-13:37:39,1 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 210223-13:37:58,738 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2conestimate".
# 210223-13:37:58,741 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_downreg/datasink".
# 210223-13:37:58,896 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 210223-13:37:58,899 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_downreg/SPM.mat -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/downreg/SPM.mat
# 210223-13:37:58,941 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_downreg/spmT_0001.nii -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/downreg/spmT_0001.nii
# 210223-13:37:58,958 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_downreg/con_0001.nii -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/downreg/con_0001.nii
# 210223-13:37:59,44 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 210223-13:37:59,47 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_alc_v_nonalc/getcontrastfiles".
# 210223-13:37:59,76 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l2analysis.getcontrastfiles".
# 210223-13:37:59,327 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 210223-13:38:01,139 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 210223-13:38:01,141 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_alc_v_nonalc/onesampttestdes".
# 210223-13:38:01,186 nipype.workflow INFO:
# 	 [Node] Cached "l2analysis.onesampttestdes" - collecting precomputed outputs
# 210223-13:38:01,187 nipype.workflow INFO:
# 	 [Node] "l2analysis.onesampttestdes" found cached.
# 210223-13:38:01,188 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_alc_v_nonalc/level2estimate".
# 210223-13:38:02,395 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 210223-13:39:05,776 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 210223-13:39:05,778 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_alc_v_nonalc/level2conestimate".
# 210223-13:39:05,976 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 210223-13:39:26,120 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2conestimate".
# 210223-13:39:26,123 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_alc_v_nonalc/datasink".
# 210223-13:39:26,304 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 210223-13:39:26,307 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_alc_v_nonalc/SPM.mat -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/alc_v_nonalc/SPM.mat
# 210223-13:39:26,355 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_alc_v_nonalc/spmT_0001.nii -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/alc_v_nonalc/spmT_0001.nii
# 210223-13:39:26,372 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_alc_v_nonalc/con_0001.nii -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/alc_v_nonalc/con_0001.nii
# 210223-13:39:26,466 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 210223-13:39:26,467 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_nonalc_react/getcontrastfiles".
# 210223-13:39:26,664 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 210223-13:39:28,549 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 210223-13:39:28,550 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_nonalc_react/onesampttestdes".
# 210223-13:39:28,731 nipype.workflow INFO:
# 	 [Node] Running "onesampttestdes" ("nipype.interfaces.spm.model.OneSampleTTestDesign")
# 210223-13:39:48,984 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.onesampttestdes".
# 210223-13:39:48,985 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_nonalc_react/level2estimate".
# 210223-13:39:49,258 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 210223-13:40:52,695 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 210223-13:40:52,697 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_nonalc_react/level2conestimate".
# 210223-13:40:52,954 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 210223-13:41:14,316 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2conestimate".
# 210223-13:41:14,318 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_nonalc_react/datasink".
# 210223-13:41:14,480 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 210223-13:41:14,483 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_nonalc_react/SPM.mat -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/nonalc_react/SPM.mat
# 210223-13:41:14,525 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_nonalc_react/spmT_0001.nii -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/nonalc_react/spmT_0001.nii
# 210223-13:41:14,541 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_nonalc_react/con_0001.nii -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/nonalc_react/con_0001.nii
# 210223-13:41:14,618 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 210223-13:41:14,620 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_rating/getcontrastfiles".
# 210223-13:41:14,796 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 210223-13:41:16,380 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 210223-13:41:16,382 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_rating/onesampttestdes".
# 210223-13:41:16,538 nipype.workflow INFO:
# 	 [Node] Running "onesampttestdes" ("nipype.interfaces.spm.model.OneSampleTTestDesign")
# 210223-13:41:37,102 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.onesampttestdes".
# 210223-13:41:37,104 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_rating/level2estimate".
# 210223-13:41:37,250 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 210223-13:42:38,571 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 210223-13:42:38,574 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_rating/level2conestimate".
# 210223-13:42:38,762 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 210223-13:42:58,648 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2conestimate".
# 210223-13:42:58,651 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_rating/datasink".
# 210223-13:42:58,790 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 210223-13:42:58,793 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_rating/SPM.mat -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/rating/SPM.mat
# 210223-13:42:58,845 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_rating/spmT_0001.nii -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/rating/spmT_0001.nii
# 210223-13:42:58,861 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_rating/con_0001.nii -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/rating/con_0001.nii
# 210223-13:42:58,939 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 210223-13:42:58,941 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_alc_react/getcontrastfiles".
# 210223-13:42:59,141 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 210223-13:43:00,566 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 210223-13:43:00,567 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_alc_react/onesampttestdes".
# 210223-13:43:00,739 nipype.workflow INFO:
# 	 [Node] Running "onesampttestdes" ("nipype.interfaces.spm.model.OneSampleTTestDesign")
# 210223-13:43:20,300 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.onesampttestdes".
# 210223-13:43:20,302 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_alc_react/level2estimate".
# 210223-13:43:20,446 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 210223-13:44:20,667 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 210223-13:44:20,670 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_alc_react/level2conestimate".
# 210223-13:44:20,873 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 210223-13:44:41,93 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2conestimate".
# 210223-13:44:41,95 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_alc_react/datasink".
# 210223-13:44:41,219 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 210223-13:44:41,221 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_alc_react/SPM.mat -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/alc_react/SPM.mat
# 210223-13:44:41,267 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_alc_react/spmT_0001.nii -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/alc_react/spmT_0001.nii
# 210223-13:44:41,283 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_alc_react/con_0001.nii -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/alc_react/con_0001.nii
# 210223-13:44:41,356 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 210223-13:44:41,357 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.getcontrastfiles" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_cue/getcontrastfiles".
# 210223-13:44:41,526 nipype.workflow INFO:
# 	 [Node] Running "getcontrastfiles" ("nipype.interfaces.utility.wrappers.Function")
# 210223-13:44:42,775 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.getcontrastfiles".
# 210223-13:44:42,777 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.onesampttestdes" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_cue/onesampttestdes".
# 210223-13:44:42,934 nipype.workflow INFO:
# 	 [Node] Running "onesampttestdes" ("nipype.interfaces.spm.model.OneSampleTTestDesign")
# 210223-13:45:03,107 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.onesampttestdes".
# 210223-13:45:03,109 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2estimate" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_cue/level2estimate".
# 210223-13:45:03,259 nipype.workflow INFO:
# 	 [Node] Running "level2estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 210223-13:46:11,417 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2estimate".
# 210223-13:46:11,419 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.level2conestimate" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_cue/level2conestimate".
# 210223-13:46:11,620 nipype.workflow INFO:
# 	 [Node] Running "level2conestimate" ("nipype.interfaces.spm.model.EstimateContrast")
# 210223-13:46:33,43 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.level2conestimate".
# 210223-13:46:33,45 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/fmriNASTest/data00/projects/MURI/data/BIDS/working/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_cue/datasink".
# 210223-13:46:33,193 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 210223-13:46:33,196 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_cue/SPM.mat -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/cue/SPM.mat
# 210223-13:46:33,239 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_cue/spmT_0001.nii -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/cue/spmT_0001.nii
# 210223-13:46:33,258 nipype.interface INFO:
# 	 sub: /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/_contrast_name_cue/con_0001.nii -> /data00/projects/MURI/data/BIDS/derivatives/nipype/task-cuereact_model-condition/l2analysis/cue/con_0001.nii
# 210223-13:46:33,337 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".

# %%
p_val = 0.001
p001_uncorrected = sp.stats.norm.isf(p_val)

for con_folder in glob.glob(os.path.join(l2analysis_path, "*")):
    if not os.path.isdir(con_folder):
        continue
    
    con_name = os.path.basename(con_folder)
    t_map = os.path.join(con_folder, "spmT_0001.nii")
    
    if not os.path.exists(t_map):
        continue
    
    plotting.plot_stat_map(
        t_map, threshold=p001_uncorrected, colorbar=True, display_mode='z',
        title=f'{con_name} (uncorr p < 0.001)')
    
    plotting.show()

# %%
#!nipypecli crash /fmriMURI/scripts/jupyterhub_users/CNLab/second_level_models/cuereact/crash-20210223-123628-dcosme@asc.upenn.edu-onesampttestdes.a9-d958e803-b1a5-48c7-8126-672179cd7f12.pklz
